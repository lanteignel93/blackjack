# %%
from blackjack import *

# %%
game = Blackjack()

# %%
game.init_game()

# %% [markdown]
# ### Let's compute the Monte-Carlo Simulation with enough games to have an accurate probability distribution

# %%
game.monte_carlo_q_sim(int(1e8))
# Out:
# 10% Complete in 323.794s
# 20% Complete in 644.196s
# 30% Complete in 956.826s
# 40% Complete in 1279.239s
# 50% Complete in 1585.837s
# 60% Complete in 1916.479s
# 70% Complete in 2249.547s
# 80% Complete in 2579.757s
# 90% Complete in 2884.971s

# %% [markdown]
# ### Let's print the values of all the different states and optimal actions/implied probability winning

# %%
game.optimal_policy(implied_prob = True)
# Out:
# {(12, True, 2): ('hit', 0.5370616955170884),
#  (12, True, 3): ('hit', 0.5548551736171697),
#  (12, True, 4): ('hit', 0.5640957681774008),
#  (12, True, 5): ('hit', 0.5776628200026529),
#  (12, True, 6): ('hit', 0.5805412086699333),
#  (12, True, 7): ('hit', 0.5640204580831666),
#  (12, True, 8): ('hit', 0.5317673571985785),
#  (12, True, 9): ('hit', 0.4884362909185758),
#  (12, True, 10): ('hit', 0.44718255430969905),
#  (12, True, 11): ('hit', 0.46116160639463677),
#  (12, False, 2): ('hit', 0.381513676205801),
#  (12, False, 3): ('stand', 0.393324454640899),
#  (12, False, 4): ('stand', 0.41462851756840796),
#  (12, False, 5): ('stand', 0.4364757871478549),
#  (12, False, 6): ('stand', 0.4224132087348085),
#  (12, False, 7): ('hit', 0.3925606412813993),
#  (12, False, 8): ('hit', 0.3640826635159167),
#  (12, False, 9): ('hit', 0.3300831291330819),
#  (12, False, 10): ('hit', 0.3096426977501247),
#  (12, False, 11): ('hit', 0.35635925403782986),
# ...

# %% [markdown]
# ## In this section we will print the grid of actions based on if there is a Usable Ace or not

# %% [markdown]
# ### The green squares represent "stands" and red squares represent "hit"

# %% [markdown]
# Without usable ace

# %%
game.plot_optimal_policy(is_ace = False)

# %% [markdown]
# With usable ace

# %%
game.plot_optimal_policy(is_ace = True)
